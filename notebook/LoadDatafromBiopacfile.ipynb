# %% [markdown]
# # Load data from Biopac file

# %%
import neurokit2 as nk
data, sampling_rate = nk.read_acqknowledge('../RAW_data/PB5')

# %%
data
# Out:
#          ECG (.5 - 35 Hz)  EDA (0 - 35 Hz)
# 0               -0.016174         0.987244
# 1               -0.013733         0.987244
# 2               -0.011902         0.987244
# 3               -0.010986         0.987244
# 4               -0.010376         0.987244
# ...                   ...              ...
# 5882435         -0.076904         7.791138
# 5882436         -0.079346         7.788086
# 5882437         -0.078430         7.786560
# 5882438         -0.073242         7.785034
# 5882439         -0.062256         7.783508
#
# [5882440 rows x 2 columns]

# %%
sampling_rate
# Out:
# np.float64(1000.0)

# %%
nk.signal_plot(data, subplots=True)
